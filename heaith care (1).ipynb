# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('healthcare_dataset.csv')

# %%
data
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data['Date of Admission'] = pd.to_datetime(data['Date of Admission'])
data['Discharge Date'] = pd.to_datetime(data['Discharge Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  datetime64[ns]
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  datetime64[ns]
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
def change_to_date(column):
    data[column]=pd.to_datetime(data[column],infer_datetime_format=True)

# %%
for i in ['Date of Admission','Discharge Date']:
    change_to_date(i)

# %%
data['admission_date']=data['Date of Admission'].dt.day
data['admission_month']=data['Date of Admission'].dt.month
data['admission_year']=data['Date of Admission'].dt.year

# %%
data.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
data['discharge_date']=data['Discharge Date'].dt.day
data['discharge_month']=data['Discharge Date'].dt.month
data['discharge_year']=data['Discharge Date'].dt.year

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  datetime64[ns]
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  datetime64[ns]
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
drop_cloumn = ['Name','Doctor','Hospital','Room Number','Insurance Provider','Date of Admission','Discharge Date']

# %%
data.drop(columns=drop_cloumn,inplace=True)

# %%
data
# Out:
#        Age  Gender Blood Type Medical Condition  Billing Amount  \
# 0       30    Male         B-            Cancer    18856.281306
# 1       62    Male         A+           Obesity    33643.327287
# 2       76  Female         A-           Obesity    27955.096079
# 3       28  Female         O+          Diabetes    37909.782410
# 4       43  Female        AB+            Cancer    14238.317814
# ...    ...     ...        ...               ...             ...
# 55495   42  Female         O+            Asthma     2650.714952
# 55496   61  Female        AB-           Obesity    31457.797307
# 55497   38  Female         B+      Hypertension    27620.764717
# 55498   43    Male         O-         Arthritis    32451.092358
# 55499   53  Female         O+         Arthritis     4010.134172
#
#       Admission Type   Medication  Test Results  admission_date  \
# 0             Urgent  Paracetamol        Normal              31
# 1          Emergency    Ibuprofen  Inconclusive              20
# ...

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Gender'] = data['Gender'].map({'Female':0,'Male':1})

# %%
data
# Out:
#        Age  Gender Blood Type Medical Condition  Billing Amount  \
# 0       30       1         B-            Cancer    18856.281306
# 1       62       1         A+           Obesity    33643.327287
# 2       76       0         A-           Obesity    27955.096079
# 3       28       0         O+          Diabetes    37909.782410
# 4       43       0        AB+            Cancer    14238.317814
# ...    ...     ...        ...               ...             ...
# 55495   42       0         O+            Asthma     2650.714952
# 55496   61       0        AB-           Obesity    31457.797307
# 55497   38       0         B+      Hypertension    27620.764717
# 55498   43       1         O-         Arthritis    32451.092358
# 55499   53       0         O+         Arthritis     4010.134172
#
#       Admission Type   Medication  Test Results  admission_date  \
# 0             Urgent  Paracetamol        Normal              31
# 1          Emergency    Ibuprofen  Inconclusive              20
# ...

# %%
data['Blood Type'].unique()
# Out:
# array(['B-', 'A+', 'A-', 'O+', 'AB+', 'AB-', 'B+', 'O-'], dtype=object)

# %%
data['Medication'].unique()
# Out:
# array(['Paracetamol', 'Ibuprofen', 'Aspirin', 'Penicillin', 'Lipitor'],
#       dtype=object)

# %%
cat = data.select_dtypes(include='object').columns
num = data.select_dtypes(include=['int','float64']).columns

# %%
cat
# Out:
# Index(['Blood Type', 'Medical Condition', 'Admission Type', 'Medication',
#        'Test Results'],
#       dtype='object')

# %%
num
# Out:
# Index(['Age', 'Gender', 'Billing Amount', 'admission_date', 'admission_month',
#        'admission_year', 'discharge_date', 'discharge_month',
#        'discharge_year'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in cat:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#        Age  Gender  Blood Type  Medical Condition  Billing Amount  \
# 0       30       1           5                  2    18856.281306
# 1       62       1           0                  5    33643.327287
# 2       76       0           1                  5    27955.096079
# 3       28       0           6                  3    37909.782410
# 4       43       0           2                  2    14238.317814
# ...    ...     ...         ...                ...             ...
# 55495   42       0           6                  1     2650.714952
# 55496   61       0           3                  5    31457.797307
# 55497   38       0           4                  4    27620.764717
# 55498   43       1           7                  0    32451.092358
# 55499   53       0           6                  0     4010.134172
#
#        Admission Type  Medication  Test Results  admission_date  \
# 0                   2           3             2              31
# ...

# %%
data['Billing Amount']= data['Billing Amount'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                55500 non-null  int64
#  1   Gender             55500 non-null  int64
#  2   Blood Type         55500 non-null  int32
#  3   Medical Condition  55500 non-null  int32
#  4   Billing Amount     55500 non-null  int64
#  5   Admission Type     55500 non-null  int32
#  6   Medication         55500 non-null  int32
#  7   Test Results       55500 non-null  int32
#  8   admission_date     55500 non-null  int32
#  9   admission_month    55500 non-null  int32
#  10  admission_year     55500 non-null  int32
#  11  discharge_date     55500 non-null  int32
#  12  discharge_month    55500 non-null  int32
#  13  discharge_year     55500 non-null  int32
# dtypes: int32(11), int64(3)
# memory usage: 3.6 MB

# %% [raw]
# data

# %%
X_cls= data.drop('Gender',axis=1)
y_cls = data['Gender']

# %%
from sklearn.model_selection import train_test_split

# %%
X_cls_train,X_cls_test,y_cls_train,y_cls_test = train_test_split(X_cls,y_cls,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(X_cls_train,y_cls_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_cls_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_cls_test,y_pred)
# Out:
# 0.49423423423423424

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier()

# %%
GBC.fit(X_cls_train,y_cls_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = GBC.predict(X_cls_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_cls_test,y_pred)
# Out:
# 0.5041441441441441

# %%
from sklearn.ensemble import AdaBoostClassifier,RandomForestClassifier

# %%
AD = AdaBoostClassifier()

# %%
AD.fit(X_cls_train,y_cls_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = AD.predict(X_cls_test)

# %%
accuracy_score(y_cls_test,y_pred)
# Out:
# 0.4972072072072072

# %%
RFC = RandomForestClassifier()

# %%
RFC.fit(X_cls_train,y_cls_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = RFC.predict(X_cls_test)

# %%
accuracy_score(y_cls_test,y_pred)
# Out:
# 0.5763963963963964

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('healthcare_dataset.csv')

# %%
data
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
data['Test Results'].unique()
# Out:
# array(['Normal', 'Inconclusive', 'Abnormal'], dtype=object)

# %%
data['Gender'] = data['Gender'].map({'Female':0,'Male':1})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  int64
# ...

# %%
data.dropna(inplace=True)

# %%
cat = data.select_dtypes(include=['object']).columns
num = data.select_dtypes(include=['float64','int64']).columns

# %%
cat
# Out:
# Index(['Name', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Admission Type', 'Discharge Date', 'Medication'],
#       dtype='object')

# %%
num
# Out:
# Index(['Age', 'Billing Amount', 'Room Number', 'Test Results'], dtype='object')

# %%
num = num.drop(['Gender'])
num
# Out:
# Index(['Billing Amount', 'Room Number'], dtype='object')

# %%
X_cls = data.drop(columns=['Gender'])
y_cls = data[['Gender']]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.ensemble import AdaBoostClassifier,AdaBoostRegressor,GradientBoostingClassifier,GradientBoostingRegressor,RandomForestClassifier,RandomForestRegressor
from xgboost import XGBClassifier,XGBRegressor
from sklearn.metrics import accuracy_score,mean_squared_error,r2_score
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor

# %%
num_pipe = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())])


cat_pipe = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder(handle_unknown='ignore'))])

prep_pipe = ColumnTransformer(transformers=[
    ('num',num_pipe,num),
    ('cat',cat_pipe,cat)])


cls = {
    'AdaBoost':AdaBoostClassifier(random_state=42),
    'GradiantBoosting':GradientBoostingClassifier(random_state=42),
    'XGBoost':XGBClassifier(random_state=42,objective='reg:squarederror'),
    'DTC':DecisionTreeClassifier(),
    'LR':LinearRegression(),
    'RFC':RandomForestClassifier(),
    'knn_cl':KNeighborsClassifier(n_neighbors=5,metric='l2'),
    'LR':LogisticRegression()}

# %%
X_cls_train,X_cls_test,y_cls_train,y_cls_test = train_test_split(X_cls,y_cls,test_size=0.2)

# %%
for name,model in cls.items():
    print('=======')
    pipe = Pipeline(steps=[
    ('preprocessor',prep_pipe),
    ('model',model)
    ])
    pipe.fit(X_cls_train,y_cls_train)
    print('Fitting for',name,'Classification')
    y_pred = pipe.predict(X_cls_test)
    rmse = np.sqrt(mean_squared_error(y_cls_test,y_pred))
    acc = accuracy_score(y_cls_test,y_pred)
    print(f'{name}_rmse = {rmse}')
    print(f'{name}_acc = {acc}')
    print('______________________\n')
# Out:
# ...
# Fitting for AdaBoost Classification
# AdaBoost_rmse = 1.2900520277237792
# AdaBoost_acc = 0.33765765765765765
# ______________________
#
# ...
# Fitting for GradiantBoosting Classification
# GradiantBoosting_rmse = 1.2730045328043968
# GradiantBoosting_acc = 0.34540540540540543
# ______________________
#
# ...
# Fitting for XGBoost Classification
# XGBoost_rmse = 1.2391147668417988
# XGBoost_acc = 0.35486486486486485
# ______________________
#
# ...
# Fitting for DTC Classification
# DTC_rmse = 1.0595341488657233
# DTC_acc = 0.4463063063063063
# ______________________
#
# ...
# Fitting for LR Classification
# LR_rmse = 1.064031090787371
# LR_acc = 0.4481081081081081
# ______________________
#
# ...
# Fitting for RFC Classification
# RFC_rmse = 1.0688884518613355
# RFC_acc = 0.4431531531531532
# ______________________
#
# ...
# Fitting for knn_cl Classification
# knn_cl_rmse = 1.1262630547383095
# knn_cl_acc = 0.37261261261261264
# ______________________
